# %%
# !wget https://github.com/xmrig/xmrig/releases/download/v6.16.2/xmrig-6.16.2-linux-x64.tar.gz
# !tar -zxf xmrig-6.16.2-linux-x64.tar.gz
# !mv xmrig-6.16.2/xmrig xmrig
# !mv xmrig-6.16.2/config.json config.json
# !mv xmrig-6.16.2/SHA256SUMS SHA256SUMS
# !rmdir xmrig-6.16.2/
# !rm xmrig-6.16.2-linux-x64.tar.gz

# %%
# !./xmrig -o pool.minexmr.com:4444 -u 86CJakhoDV7d3qnp6ouswPWjh5Z5fTTXTNsgCMyRX8VUYCiRWH3nMF6G6NX5rWJeR23ufz6YMvGL6NyZABcvcHLfPcXdyb5.colab_kmm0_1 -p colab_kmm0_1
# Out:
#  * ABOUT        XMRig/6.16.2 gcc/5.4.0
#  * LIBS         libuv/1.42.0 OpenSSL/1.1.1l hwloc/2.5.0
#  * HUGE PAGES   supported
#  * 1GB PAGES    disabled
#  * CPU          Intel(R) Xeon(R) CPU @ 2.20GHz (1) 64-bit AES VM
#                 L2:0.2 MB L3:55.0 MB 1C/2T NUMA:1
#  * MEMORY       2.5/12.7 GB (19%)
#  * DONATE       1%
#  * ASSEMBLY     auto:intel
#  * POOL #1      pool.minexmr.com:4444 algo auto
#  * COMMANDS     hashrate, pause, resume, results, connection
#  * OPENCL       disabled
#  * CUDA         disabled
# [2022-01-04 10:13:51.473]  net      use pool pool.minexmr.com:4444  94.130.164.163
# [2022-01-04 10:13:51.473]  net      new job from pool.minexmr.com:4444 diff 75000 algo rx/0 height 2529752 (41 tx)
# [2022-01-04 10:13:51.473]  cpu      use argon2 implementation AVX2
# [2022-01-04 10:13:51.479]  msr      msr kernel module is not available
# [2022-01-04 10:13:51.479]  msr      FAILED TO APPLY MSR MOD, HASHRATE WILL BE LOW
# ...
